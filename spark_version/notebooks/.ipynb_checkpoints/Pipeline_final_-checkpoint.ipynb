# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pyspark.sql.types import * 
from pyspark.sql import SparkSession, DataFrame as SparkDataFrame
import pyspark.sql.functions as F
from pyspark.sql.functions import col,isnan, when, count, coalesce
from pyspark import SparkContext
from pyspark.sql import SQLContext
from pyspark.sql.window import Window
from pyspark.sql.functions import col, lag, lead
import json
from functools import reduce
import sys
from cassandra.cluster import Cluster
import os
import time
import warnings
import json
from pyspark.sql import Window
from pyspark.sql.functions import lag, col
import mysql.connector as database
import time
import sqlalchemy

# from mock.tasks import adiciona_carro}
cluster = Cluster(['cassandra'])
session = cluster.connect()

ss = SparkSession.builder \
           .appName('SparkByExamples') \
           .config("spark.jars", "/usr/share/java/mariadb-java-client.jar") \
           .getOrCreate()
sql = SQLContext(ss)

warnings.simplefilter(action='ignore', category=FutureWarning)

session.execute("USE simulacao")

params = json.load(open('./mock/parametros.json'))

connection = database.connect(
    host="host.docker.internal",
    port=3306,
    user="root",
    password="secret"
)

cursor = connection.cursor()
cursor.execute("USE dashboard;")
# Out:
# /usr/local/spark/python/pyspark/sql/context.py:112: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(

# %%
start_time = time.time()
total = 0
last = 0
i = 0
#for i in range(100):
while i < 100:
    start_time2 = time.time()
    
    a, b = 50*i, 50*i + 50
    
    # a = last
    # try:
    #     b = list(session.execute("SELECT MAX(tempo_da_simulacao) FROM simulacao"))[0][0]
    #     last = b
    # except:
    #     b = 0
    
    st=time.time()
    
    query = f"SELECT * FROM simulacao WHERE tempo_da_simulacao >= {a} AND tempo_da_simulacao <= {b} ALLOW FILTERING;"
    r = list(session.execute(query))
    
    et=time.time()
    
    if r != []:
        print(f"Tempo de extração do banco: {et-st}")
        i+=1
        
        st=time.time()
        
        df = ss.createDataFrame(r)
        
        p = [[key]+list(params[key].values()) for key in params.keys()]
        p = ss.createDataFrame(p, ["Rodovia"]+list(params[list(params.keys())[0]].keys()))
        
        Velocidades_Maximas = p.select(F.col('rodovia'), F.col("VelocidadeMaxima"))
        Aceleracoes_Maximas = p.select(F.col('rodovia'), 0.8*F.col("AceleracaoMaxima"))
        Aceleracoes_Maximas = Aceleracoes_Maximas.withColumnRenamed("(AceleracaoMaxima * 0.8)", "AceleracaoMaxima")
        
        collision_tolerance = 1
        collision_tolerance_quad = 0.5
        windowSpec = Window.partitionBy("placa").orderBy("tempo_da_simulacao")
        
        df = df.withColumn("prev_pos_y", lag("pos_y", 1).over(windowSpec))
        df = df.withColumn("prev_tempo_da_simulacao", lag("tempo_da_simulacao", 1).over(windowSpec))
        df = df.withColumn("vel_y", (col("pos_y") - col("prev_pos_y")) / (col("tempo_da_simulacao") - col("prev_tempo_da_simulacao")))
        df = df.withColumn("prev_vel_y", lag("vel_y", 1).over(windowSpec))
        df = df.withColumn("acel_y", (col("vel_y") - col("prev_vel_y")) / (col("tempo_da_simulacao") - col("prev_tempo_da_simulacao")))
        
        df = df.withColumn("posicao_prevista", col("pos_y") + col("vel_y") * (collision_tolerance) + col("acel_y") * collision_tolerance_quad)
        
        window_spec_rf = Window.partitionBy("rodovia", "pos_x").orderBy('pos_y')
        lag_column = col("posicao_prevista") - lag(col("posicao_prevista")).over(window_spec_rf)
        lead_column = lead(col("posicao_prevista")).over(window_spec_rf) - col("posicao_prevista")
        
        # Add the lag column to the DataFrame
        df = df.withColumn("Risco_Colisão", when(((lag_column < 0) & (col("rodovia") == lag(col("rodovia")).over(window_spec_rf)) & (col("pos_x") == lag(col("pos_x")).over(window_spec_rf)))| ((lead_column < 0) & (col("rodovia") == lead(col("rodovia")).over(window_spec_rf)) & (col("pos_x") == lead(col("pos_x")).over(window_spec_rf))), 1).otherwise(0))
        
        df = df.join(Velocidades_Maximas,on='rodovia',how='left')
        df = df.join(Aceleracoes_Maximas,on='rodovia',how='left')
        
        df = df.withColumn('acima_vel',F.abs(col('vel_y'))>F.abs(col('VelocidadeMaxima')))
        df = df.withColumn('acima_acel',F.abs(col('acel_y'))>F.abs(col('AceleracaoMaxima')))
        
        df = df.withColumn("troca_faixa", col("pos_x") != lag("pos_x", 1).over(windowSpec))
        
        # contador de trocas
        
        df = df.withColumn('multado',((F.col('acima_vel') == 1) & (lag('acima_vel').over(windowSpec) == 0)))
        
        windowSpec = Window.partitionBy("placa",'rodovia').orderBy('tempo_da_simulacao')
        
        df = df.withColumn("prev_pos_y", lag("pos_y", 1).over(windowSpec))
        df = df.withColumn("on_road", (((col("pos_y") > 0) & (col('pos_y') < 800)) & (col("prev_pos_y") > 0)).cast("int"))
        df = df.withColumn('time_on_road',F.lit(0))
    
        data = df.select('placa','pos_x','pos_y','acel_y','vel_y', 'rodovia', 'tempo_da_simulacao',F.col('multado').cast('int'),'Risco_Colisão',F.col('troca_faixa'))#,'acima_vel')
        datap = data.toPandas()

        et=time.time()
        print(f"Tempo de cálculo do Spark: {et-st}")

        st=time.time()
        query = f""" INSERT IGNORE INTO carros (placa, pos_x, pos_y, aceleracao, velocidade, rodovia, horario_registro, multas, risco_colisao, direcao_perigosa)
    
                    VALUES {','.join([str(i) for i in list(datap.to_records(index=False))])};
                    
                    """.replace("None", "NULL").replace("\n", "").replace("nan", "NULL")
    
        cursor.execute(query)
        connection.commit()
        et=time.time()
        print(f"Tempo para exportar para o banco: {et-st}")

        # st=time.time()
        
        # datap.to_sql(name='carros', con=connection, if_exists='append', index=False)
        
        # et=time.time()
        # print(f"Tempo para exportar para o banco: {et-st}")
    
    
        end_time = time.time()
        elapsed_time = end_time - start_time2
        total = total + elapsed_time
        print(f"For iterarion {i} - Elapsed time: {elapsed_time} seconds")
    
        cursor.execute("SELECT COUNT(*) FROM carros;")
        print("Número de linhas no DB:", cursor.fetchall()[0][0])

print()
print(f"Total time for {i+1} iterations: {total}")
# Out:
# Tempo de extração do banco: 0.13943767547607422
# Tempo de cálculo do Spark: 15.702453851699829
# Tempo para exportar para o banco: 0.14258742332458496
# For iterarion 1 - Elapsed time: 15.98473334312439 seconds
# Número de linhas no DB: 134
# Tempo de extração do banco: 0.01318049430847168
# Tempo de cálculo do Spark: 2.8985657691955566
# Tempo para exportar para o banco: 0.1776111125946045
# For iterarion 2 - Elapsed time: 3.0895345211029053 seconds
# Número de linhas no DB: 426
# Tempo de extração do banco: 0.014601945877075195
# Tempo de cálculo do Spark: 2.344012498855591
# Tempo para exportar para o banco: 0.26624417304992676
# For iterarion 3 - Elapsed time: 2.6253013610839844 seconds
# Número de linhas no DB: 853
# Tempo de extração do banco: 0.017525911331176758
# Tempo de cálculo do Spark: 2.2139041423797607
# Tempo para exportar para o banco: 0.25888562202453613
# For iterarion 4 - Elapsed time: 2.49058198928833 seconds
# Número de linhas no DB: 1393
# Tempo de extração do banco: 0.021725893020629883
# Tempo de cálculo do Spark: 2.2556777000427246
# Tempo para exportar para o banco: 0.27788424491882324
# For iterarion 5 - Elapsed time: 2.555868148803711 seconds
# Número de linhas no DB: 1902
# Tempo de extração do banco: 0.01132822036743164
# Tempo de cálculo do Spark: 2.5609776973724365
# Tempo para exportar para o banco: 0.34131884574890137
# For iterarion 6 - Elapsed time: 2.9139533042907715 seconds
# Número de linhas no DB: 2616
# Tempo de extração do banco: 0.01089930534362793
# Tempo de cálculo do Spark: 2.4813551902770996
# Tempo para exportar para o banco: 0.35270023345947266
# For iterarion 7 - Elapsed time: 2.8452045917510986 seconds
# Número de linhas no DB: 3409
# Tempo de extração do banco: 0.01525568962097168
# Tempo de cálculo do Spark: 2.094510555267334
# Tempo para exportar para o banco: 0.31662917137145996
# For iterarion 8 - Elapsed time: 2.426877498626709 seconds
# Número de linhas no DB: 4137
# Tempo de extração do banco: 0.010378599166870117
# Tempo de cálculo do Spark: 1.876732587814331
# Tempo para exportar para o banco: 0.35034656524658203
# For iterarion 9 - Elapsed time: 2.237692356109619 seconds
# Número de linhas no DB: 4865
# Tempo de extração do banco: 0.010982513427734375
# Tempo de cálculo do Spark: 1.8693454265594482
# Tempo para exportar para o banco: 0.28887367248535156
# For iterarion 10 - Elapsed time: 2.1694464683532715 seconds
# Número de linhas no DB: 5450
# Tempo de extração do banco: 0.008354902267456055
# Tempo de cálculo do Spark: 1.8635413646697998
# Tempo para exportar para o banco: 0.2522702217102051
# For iterarion 11 - Elapsed time: 2.1247594356536865 seconds
# Número de linhas no DB: 6038
# Tempo de extração do banco: 0.010218620300292969
# Tempo de cálculo do Spark: 1.8742494583129883
# Tempo para exportar para o banco: 0.23524975776672363
# For iterarion 12 - Elapsed time: 2.1201882362365723 seconds
# Número de linhas no DB: 6548
# Tempo de extração do banco: 0.00852823257446289
# Tempo de cálculo do Spark: 1.8982272148132324
# Tempo para exportar para o banco: 0.25939512252807617
# For iterarion 13 - Elapsed time: 2.1664059162139893 seconds
# Número de linhas no DB: 7103
# Tempo de extração do banco: 0.011207818984985352
# Tempo de cálculo do Spark: 1.834014654159546
# Tempo para exportar para o banco: 0.2161269187927246
# For iterarion 14 - Elapsed time: 2.061901092529297 seconds
# Número de linhas no DB: 7656
# Tempo de extração do banco: 0.005170345306396484
# Tempo de cálculo do Spark: 1.9265189170837402
# Tempo para exportar para o banco: 0.1691124439239502
# For iterarion 15 - Elapsed time: 2.1009654998779297 seconds
# Número de linhas no DB: 7915
# Tempo de extração do banco: 0.011347055435180664
# Tempo de cálculo do Spark: 1.6518528461456299
# Tempo para exportar para o banco: 0.11009788513183594
# For iterarion 16 - Elapsed time: 1.773491621017456 seconds
# Número de linhas no DB: 8101
# Tempo de extração do banco: 0.006850719451904297
# Tempo de cálculo do Spark: 1.6239557266235352
# Tempo para exportar para o banco: 0.02111649513244629
# For iterarion 17 - Elapsed time: 1.652371883392334 seconds
# Número de linhas no DB: 8132
# Tempo de extração do banco: 0.011316061019897461
# Tempo de cálculo do Spark: 1.8988230228424072
# Tempo para exportar para o banco: 0.0069811344146728516
# For iterarion 18 - Elapsed time: 1.917405366897583 seconds
# Número de linhas no DB: 8134

# %%
cursor.execute("SELECT COUNT(*) FROM carros;")

# %%
cursor.fetchall()
# Out:
# [(4825,)]

# %%
cursor.execute("SELECT * FROM carros;")

# %%
for j in cursor.fetchall():
    print(j)
# Out:
# ('COL5F67', 16, 'BR-116', 475.0, 56.0, None, None, None, 0, None)
# ('COL5F67', 18, 'BR-116', 475.0, 59.1, None, 1.55, 0, 0, 0)
# ('COL5F67', 19, 'BR-116', 475.0, 62.35, 1.7, 3.25, 0, 0, 0)
# ('COL5F67', 20, 'BR-116', 475.0, 65.75, 0.15, 3.4, 0, 1, 0)
# ('COL5F67', 21, 'BR-116', 475.0, 69.3, 0.15, 3.55, 0, 0, 0)
# ('COL5F67', 22, 'BR-116', 475.0, 73.0, 0.15, 3.7, 0, 0, 0)
# ('BOL5P67', 23, 'BR-116', 565.0, 59.0, None, None, None, 0, None)
# ('COL5F67', 23, 'BR-116', 475.0, 76.85, 0.15, 3.85, 0, 1, 0)
# ('BOL5P67', 24, 'BR-116', 565.0, 68.0, None, 9.0, 0, 0, 0)
# ('COL5F67', 24, 'BR-116', 475.0, 80.85, 0.15, 4.0, 0, 0, 0)
# ('BOL5P67', 25, 'BR-116', 565.0, 77.1, 0.1, 9.1, 1, 0, 0)
# ('COL5F67', 25, 'BR-116', 475.0, 85.0, 0.15, 4.15, 0, 1, 0)
# ('BOL5P67', 26, 'BR-116', 565.0, 86.35, 0.15, 9.25, 0, 1, 0)
# ('COL5F67', 26, 'BR-116', 475.0, 89.3, 0.15, 4.3, 0, 1, 0)
# ('BOL5P67', 27, 'BR-116', 565.0, 95.75, 0.15, 9.4, 0, 1, 0)
# ('COL5F67', 27, 'BR-116', 475.0, 93.75, 0.15, 4.45, 0, 1, 0)
# ('BOL5P67', 28, 'BR-116', 565.0, 105.3, 0.15, 9.55, 0, 0, 0)
# ('COL5F67', 28, 'BR-116', 475.0, 98.35, 0.15, 4.6, 0, 1, 0)
# ('BOL5P67', 29, 'BR-116', 565.0, 115.0, 0.15, 9.7, 0, 0, 0)
# ('COL5F67', 29, 'BR-116', 475.0, 103.1, 0.15, 4.75, 0, 1, 0)
# ('BOL5P67', 30, 'BR-116', 565.0, 124.85, 0.15, 9.85, 0, 1, 0)
# ('COL5F67', 30, 'BR-116', 475.0, 108.0, 0.15, 4.9, 0, 1, 0)
# ('SUR8W90', 30, 'BR-116', 565.0, 52.0, None, None, None, 0, None)
# ('BOL5P67', 31, 'BR-116', 565.0, 134.85, 0.15, 10.0, 0, 0, 0)
# ('COL5F67', 31, 'BR-116', 475.0, 113.05, 0.15, 5.05, 0, 1, 0)
# ('SUR8W90', 31, 'BR-116', 565.0, 54.0, None, 2.0, 0, 0, 0)
# ('BOL5P67', 32, 'BR-116', 565.0, 145.0, 0.15, 10.15, 0, 0, 0)
# ('COL5F67', 32, 'BR-116', 475.0, 118.25, 0.15, 5.2, 0, 1, 0)
# ('SUR8W90', 32, 'BR-116', 565.0, 56.1, 0.1, 2.1, 0, 0, 0)
# ('BOL5P67', 33, 'BR-116', 565.0, 155.3, 0.15, 10.3, 0, 0, 0)
# ('COL5F67', 33, 'BR-116', 475.0, 123.6, 0.15, 5.35, 0, 0, 0)
# ('SUR8W90', 33, 'BR-116', 565.0, 58.35, 0.15, 2.25, 0, 0, 0)
# ('BOL5P67', 34, 'BR-116', 565.0, 165.75, 0.15, 10.45, 0, 1, 0)
# ('COL5F67', 34, 'BR-116', 475.0, 129.1, 0.15, 5.5, 0, 0, 0)
# ('SUR8W90', 34, 'BR-116', 565.0, 60.75, 0.15, 2.4, 0, 1, 0)
# ('BOL5P67', 35, 'BR-116', 565.0, 176.35, 0.15, 10.6, 0, 0, 0)
# ('COL5F67', 35, 'BR-116', 475.0, 134.75, 0.15, 5.65, 0, 1, 0)
# ('SUR8W90', 35, 'BR-116', 565.0, 63.3, 0.15, 2.55, 0, 0, 0)
# ('BOL5P67', 36, 'BR-116', 565.0, 187.1, 0.15, 10.75, 0, 1, 0)
# ('COL5F67', 36, 'BR-116', 475.0, 140.55, 0.15, 5.8, 0, 1, 0)
# ('SUR8W90', 36, 'BR-116', 565.0, 66.0, 0.15, 2.7, 0, 0, 0)
# ('BOL5P67', 37, 'BR-116', 565.0, 198.0, 0.15, 10.9, 0, 0, 0)
# ('COL5F67', 37, 'BR-116', 475.0, 146.5, 0.15, 5.95, 0, 1, 0)
# ('SUR8W90', 37, 'BR-116', 565.0, 68.85, 0.15, 2.85, 0, 0, 0)
# ('BOL5P67', 38, 'BR-116', 565.0, 209.05, 0.15, 11.05, 0, 0, 0)
# ('COL5F67', 38, 'BR-116', 475.0, 152.6, 0.15, 6.1, 0, 0, 0)
# ('SUR8W90', 38, 'BR-116', 565.0, 71.85, 0.15, 3.0, 0, 0, 0)
# ('BOL5P67', 39, 'BR-116', 565.0, 220.25, 0.15, 11.2, 0, 0, 0)
# ('COL5F67', 39, 'BR-116', 475.0, 158.85, 0.15, 6.25, 0, 0, 0)
# ('SUR8W90', 39, 'BR-116', 565.0, 75.0, 0.15, 3.15, 0, 1, 0)
# ('VEN0Q12', 84, 'BR-116', 835.0, 578.8, 38.05, 30.8, 1, 0, 0)
# ('BOL3R45', 85, 'BR-116', 475.0, 116.2, 4.25, 10.7, 1, 1, 0)
# ('BRA2A34', 85, 'BR-116', 385.0, 221.75, 42.45, 27.9, 0, 1, 0)
# ('COL5F67', 85, 'BR-116', 565.0, 440.55, 0.15, 5.6, 0, 0, 0)
# ('PAR5Z67', 85, 'BR-116', 565.0, 68.0, -8.844, -12.433, 0, 0, 0)
# ('SUR4I56', 85, 'BR-116', 565.0, 120.35, 12.9, 22.4, 0, 0, 0)
# ('VEN0Q12', 85, 'BR-116', 835.0, 592.75, -16.85, 13.95, 0, 1, 0)
# ('BOL3R45', 86, 'BR-116', 475.0, 113.3, -13.6, -2.9, 0, 1, 0)
# ('BRA2A34', 86, 'BR-116', 385.0, 302.0, 52.35, 80.25, 0, 1, 0)
# ('COL5F67', 86, 'BR-116', 565.0, 446.3, 0.15, 5.75, 0, 1, 0)
# ('PAR5Z67', 86, 'BR-116', 565.0, 59.0, 3.433, -9.0, 0, 1, 0)
# ('SUR4I56', 86, 'BR-116', 565.0, 106.65, -36.1, -13.7, 0, 1, 0)
# ('SUR8W90', 86, 'BR-116', 475.0, 257.25, 31.562, 27.425, 0, 1, 0)
# ('VEN0Q12', 86, 'BR-116', 835.0, 523.55, -83.15, -69.2, 0, 1, 0)
# ('BOL3R45', 87, 'BR-116', 475.0, 140.05, 29.65, 26.75, 1, 1, 0)
# ('BOL5P67', 87, 'BR-116', 565.0, 826.1, -20.944, -42.233, 0, 0, 0)
# ('BRA2A34', 87, 'BR-116', 385.0, 387.05, 4.8, 85.05, 0, 1, 0)
# ('COL5F67', 87, 'BR-116', 565.0, 452.2, 0.15, 5.9, 0, 0, 0)
# ('PAR5Z67', 87, 'BR-116', 565.0, 176.35, 126.35, 117.35, 1, 1, 0)
# ('SUR4I56', 87, 'BR-116', 565.0, 145.0, 52.05, 38.35, 0, 1, 0)
# ('SUR8W90', 87, 'BR-116', 475.0, 198.4, -86.275, -58.85, 0, 1, 0)
# ('VEN4E56', 87, 'BR-116', 745.0, 781.8, None, None, None, 0, None)
# ('COL5F67', 88, 'BR-116', 565.0, 458.25, 0.15, 6.05, 0, 0, 0)
# ('SUR4I56', 88, 'BR-116', 565.0, 142.85, -40.5, -2.15, 0, 1, 0)
# ('VEN0Q12', 88, 'BR-116', 835.0, 627.05, 60.475, 51.75, 0, 1, 0)
# ('BOL3R45', 89, 'BR-116', 475.0, 134.7, -14.713, -2.675, 0, 1, 0)
# ('BRA2A34', 89, 'BR-116', 385.0, 284.75, -68.1, -51.15, 0, 1, 0)
# ('BOL3R45', 90, 'BR-116', 475.0, 171.55, 39.525, 36.85, 1, 1, 0)
# ('BRA2A34', 90, 'BR-116', 385.0, 276.35, 42.75, -8.4, 0, 1, 0)
# ('COL5F67', 90, 'BR-116', 565.0, 477.3, 1.738, 9.525, 1, 0, 0)
# ('GUY3V45', 90, 'BR-116', 835.0, 852.05, None, None, None, 0, None)
# ('VEN0Q12', 95, 'BR-116', 835.0, 490.25, 4.35, -10.65, 0, 1, 0)
# ('VEN4E56', 95, 'BR-116', 745.0, 825.3, -62.2, -26.7, 0, 1, 0)
# ('GUY3V45', 96, 'BR-116', 835.0, 840.3, 39.65, 34.05, 1, 1, 0)
# ('BOL3R45', 97, 'BR-116', 475.0, 122.45, 0.362, -20.525, 0, 1, 0)
# ('BRA2A34', 97, 'BR-116', 385.0, 236.6, -39.938, -37.125, 0, 1, 0)
# ('COL5F67', 97, 'BR-116', 565.0, 567.0, -24.875, 4.15, 0, 1, 0)
# ('PAR5Z67', 97, 'BR-116', 565.0, 86.35, -62.8, -45.0, 0, 1, 0)
# ('SUR4I56', 97, 'BR-116', 565.0, 145.0, -6.4, 0.0, 0, 1, 0)
# ('VEN0Q12', 97, 'BR-116', 835.0, 583.4, 28.613, 46.575, 0, 1, 0)
# ('BOL3R45', 98, 'BR-116', 475.0, 194.3, 92.375, 71.85, 0, 1, 0)
# ('BRA2A34', 98, 'BR-116', 385.0, 472.85, 273.375, 236.25, 0, 0, 0)
# ('COL5F67', 98, 'BR-116', 565.0, 575.45, 4.3, 8.45, 0, 1, 0)
# ('SUR8W90', 98, 'BR-116', 475.0, 264.45, 0.0, 0.0, 0, 0, 0)
# ('VEN0Q12', 98, 'BR-116', 835.0, 493.75, -136.225, -89.65, 0, 1, 0)
# ('BOL3R45', 99, 'BR-116', 475.0, 194.3, -71.85, 0.0, 0, 1, 0)
# ('BRA2A34', 99, 'BR-116', 385.0, 450.5, -258.6, -22.35, 0, 1, 0)
# ('COL5F67', 99, 'BR-116', 565.0, 584.05, 0.15, 8.6, 0, 0, 0)
# ('GUY3V45', 99, 'BR-116', 835.0, 800.75, -15.744, -13.183, 0, 0, 0)
# ('PAR5Z67', 99, 'BR-116', 565.0, 176.35, 45.0, 45.0, 0, 1, 0)
# ('SUR4I56', 99, 'BR-116', 565.0, 145.0, 0.0, 0.0, 0, 0, 0)
# ('SUR8W90', 99, 'BR-116', 475.0, 264.45, 0.0, 0.0, 0, 0, 0)
# ('VEN4E56', 99, 'BR-116', 745.0, 714.8, -0.231, -27.625, 0, 0, 0)
# ('VEN2O34', 100, 'BR-116', 385.0, 74.1, None, None, None, 0, None)
# ('BOL3R45', 101, 'BR-116', 475.0, 194.3, None, None, None, 0, None)
# ('BRA2A34', 101, 'BR-116', 385.0, 439.55, None, None, None, 0, None)
# ('COL5F67', 101, 'BR-116', 565.0, 592.8, None, None, None, 0, None)
# ('GUY3V45', 101, 'BR-116', 835.0, 846.15, None, None, None, 0, None)
# ('PAR5Z67', 101, 'BR-116', 565.0, 176.35, None, None, None, 0, None)
# ('SUR4I56', 101, 'BR-116', 565.0, 145.0, None, None, None, 0, None)
# ('SUR8W90', 101, 'BR-116', 475.0, 264.45, None, None, None, 0, None)
# ('VEN0Q12', 101, 'BR-116', 835.0, 539.65, None, None, None, 0, None)
# ('VEN4E56', 101, 'BR-116', 745.0, 756.3, None, None, None, 0, None)
# ('BOL3R45', 102, 'BR-116', 475.0, 194.3, None, 0.0, 0, 0, 0)
# ('BRA2A34', 102, 'BR-116', 385.0, 555.8, None, 116.25, None, 0, 0)
# ('BRA6W78', 102, 'BR-116', 745.0, 828.5, None, None, None, 0, None)
# ('COL5F67', 102, 'BR-116', 565.0, 610.75, None, 17.95, None, 0, 0)
# ('GUY3V45', 102, 'BR-116', 745.0, 749.5, None, -96.65, None, 0, 1)
# ('PAR5Z67', 102, 'BR-116', 565.0, 176.35, None, 0.0, 0, 0, 0)
# ('PER1H23', 102, 'BR-116', 835.0, 864.0, None, None, None, 0, None)
# ('SUR4I56', 102, 'BR-116', 565.0, 145.0, None, 0.0, 0, 0, 0)
# ('SUR8W90', 102, 'BR-116', 475.0, 264.45, None, 0.0, 0, 0, 0)
# ('URU6M78', 102, 'BR-116', 655.0, 868.0, None, None, None, 0, None)
# ('VEN0Q12', 102, 'BR-116', 835.0, 461.0, None, -78.65, None, 0, 0)
# ('VEN2O34', 102, 'BR-116', 385.0, 153.75, None, 39.825, None, 0, 0)
# ('VEN4E56', 102, 'BR-116', 745.0, 620.3, None, -136.0, None, 0, 0)
# ('BOL3R45', 103, 'BR-116', 475.0, 194.3, 0.0, 0.0, 0, 0, 0)
# ('BRA2A34', 103, 'BR-116', 385.0, 619.55, -52.5, 63.75, 0, 1, 0)
# ('COL5F67', 103, 'BR-116', 565.0, 619.95, -8.75, 9.2, 0, 0, 0)
# ('SUR4I56', 103, 'BR-116', 565.0, 145.0, 0.0, 0.0, 0, 0, 0)
# ('SUR8W90', 103, 'BR-116', 475.0, 264.45, 0.0, 0.0, 0, 0, 0)
# ('VEN0Q12', 103, 'BR-116', 835.0, 446.5, 64.15, -14.5, 0, 1, 0)
# ('BOL3R45', 104, 'BR-116', 475.0, 146.0, -48.3, -48.3, 1, 1, 0)
# ('BRA2A34', 104, 'BR-116', 385.0, 495.8, -187.5, -123.75, 0, 0, 0)
# ('GUY3V45', 104, 'BR-116', 835.0, 858.0, 75.45, 54.25, 0, 0, 1)
# ('PAR5Z67', 104, 'BR-116', 565.0, 176.35, 0.0, 0.0, 0, 0, 0)
# ('SUR4I56', 104, 'BR-116', 565.0, 145.0, 0.0, 0.0, 0, 0, 0)
# ('SUR8W90', 104, 'BR-116', 475.0, 264.45, 0.0, 0.0, 0, 0, 0)
# ('VEN0Q12', 104, 'BR-116', 835.0, 476.75, 44.75, 30.25, 0, 0, 0)
# ('VEN4E56', 104, 'BR-116', 745.0, 799.05, 112.688, 89.375, 0, 1, 0)
# ('BOL3R45', 105, 'BR-116', 475.0, 175.8, 78.1, 29.8, 0, 0, 0)
# ('BRA2A34', 105, 'BR-116', 385.0, 397.25, 25.2, -98.55, 0, 0, 0)
# ('COL5F67', 105, 'BR-116', 565.0, 648.45, 2.525, 14.25, 0, 0, 0)
# ('GUY3V45', 105, 'BR-116', 835.0, 811.8, -100.45, -46.2, 0, 1, 0)
# ('PAR5Z67', 105, 'BR-116', 565.0, 176.35, 0.0, 0.0, 0, 0, 0)
# ('SUR4I56', 105, 'BR-116', 565.0, 145.0, 0.0, 0.0, 0, 0, 0)
# ('SUR8W90', 105, 'BR-116', 475.0, 260.3, -4.15, -4.15, 0, 0, 0)
# ('VEN0Q12', 105, 'BR-116', 835.0, 508.25, 1.25, 31.5, 0, 0, 0)
# ('VEN4E56', 105, 'BR-116', 745.0, 674.55, -213.875, -124.5, 0, 1, 0)
# ('BOL3R45', 106, 'BR-116', 475.0, 194.3, -11.3, 18.5, 0, 0, 0)
# ('BRA6W78', 106, 'BR-116', 745.0, 821.75, None, -1.688, 0, 0, 0)
# ('COL5F67', 106, 'BR-116', 565.0, 678.3, 15.6, 29.85, 0, 0, 0)
# ('GUY3V45', 106, 'BR-116', 745.0, 747.5, -18.1, -64.3, 0, 0, 1)
# ('PAR5Z67', 106, 'BR-116', 565.0, 176.35, 0.0, 0.0, 0, 0, 0)
# ('PER1H23', 106, 'BR-116', 835.0, 862.0, None, -0.5, 0, 0, 0)
# ('SUR4I56', 106, 'BR-116', 565.0, 145.0, 0.0, 0.0, 0, 0, 0)
# ('URU6M78', 106, 'BR-116', 655.0, 866.0, None, -0.5, 0, 0, 0)
# ('VEN2O34', 106, 'BR-116', 385.0, 99.3, -13.359, -13.613, 0, 1, 0)
# ('VEN4E56', 106, 'BR-116', 745.0, 612.75, 62.7, -61.8, 0, 0, 0)
# ('BOL3R45', 107, 'BR-116', 475.0, 132.25, -80.55, -62.05, 0, 1, 0)
# ('PAR5Z67', 107, 'BR-116', 565.0, 134.85, -41.5, -41.5, 1, 1, 0)
# ('SUR4I56', 107, 'BR-116', 565.0, 136.45, -8.55, -8.55, 0, 0, 0)
# ('VEN4E56', 107, 'BR-116', 745.0, 843.05, 292.1, 230.3, 0, 1, 0)
# ('BOL3R45', 108, 'BR-116', 475.0, 127.8, 57.6, -4.45, 0, 1, 0)
# ('GUY3V45', 108, 'BR-116', 835.0, 774.0, 38.775, 13.25, 0, 1, 1)
# ('PAR5Z67', 108, 'BR-116', 565.0, 115.0, 21.65, -19.85, 0, 0, 0)
# ('SUR4I56', 108, 'BR-116', 565.0, 128.1, 0.2, -8.35, 0, 1, 0)
# ('SUR8W90', 108, 'BR-116', 475.0, 264.45, 1.844, 1.383, 0, 1, 0)
# ('VEN2O34', 108, 'BR-116', 385.0, 90.75, 4.669, -4.275, 0, 1, 0)
# ('VEN4E56', 108, 'BR-116', 745.0, 861.0, -212.35, 17.95, 0, 1, 0)
# ('SUR8W90', 109, 'BR-116', 475.0, 264.45, -1.383, 0.0, 0, 1, 0)
# ('BOL3R45', 110, 'BR-116', 475.0, 194.3, 18.85, 33.25, 1, 1, 0)
# ('BRA2A34', 110, 'BR-116', 385.0, 659.6, 30.204, 52.47, 0, 0, 0)
# ('COL5F67', 110, 'BR-116', 565.0, 775.95, -1.359, 24.413, 0, 0, 0)
# ('GUY3V45', 110, 'BR-116', 745.0, 743.5, -14.25, -15.25, 0, 1, 1)
# ('PAR5Z67', 110, 'BR-116', 565.0, 176.35, 25.262, 30.675, 0, 1, 0)
# ('SUR4I56', 110, 'BR-116', 565.0, 145.0, 8.4, 8.45, 0, 1, 0)
# ('SUR8W90', 110, 'BR-116', 475.0, 264.45, 0.0, 0.0, 0, 0, 0)
# ('VEN0Q12', 110, 'BR-116', 835.0, 452.15, -8.544, -11.22, 0, 1, 0)
# ('VEN4E56', 110, 'BR-116', 745.0, 561.3, -83.9, -149.85, 0, 0, 0)
# ('BOL3R45', 111, 'BR-116', 475.0, 194.3, -33.25, 0.0, 0, 1, 0)
# ('BRA2A34', 111, 'BR-116', 385.0, 743.75, 31.68, 84.15, 0, 0, 0)
# ('BRA6W78', 111, 'BR-116', 745.0, 856.0, 1.708, 6.85, 0, 1, 0)
# ('GUY3V45', 111, 'BR-116', 835.0, 758.55, 30.3, 15.05, 0, 0, 1)
# ('PAR5Z67', 111, 'BR-116', 565.0, 176.35, -30.675, 0.0, 0, 1, 0)
# ('SUR4I56', 111, 'BR-116', 565.0, 145.0, -8.45, 0.0, 0, 1, 0)
# ('SUR8W90', 111, 'BR-116', 475.0, 264.45, 0.0, 0.0, 0, 0, 0)
# ('VEN0Q12', 111, 'BR-116', 835.0, 430.75, -10.18, -21.4, 0, 1, 0)
# ('VEN2O34', 111, 'BR-116', 385.0, 116.85, 4.325, 8.7, 0, 0, 0)
# ('VEN4E56', 111, 'BR-116', 745.0, 651.0, 239.55, 89.7, 0, 1, 0)
# ('BOL3R45', 112, 'BR-116', 475.0, 194.3, 0.0, 0.0, 0, 0, 0)
# ('BRA2A34', 112, 'BR-116', 385.0, 646.1, -181.8, -97.65, 0, 1, 0)
# ('GUY3V45', 112, 'BR-116', 835.0, 779.25, 5.65, 20.7, 0, 1, 0)
# ('PAR5Z67', 112, 'BR-116', 565.0, 176.35, 0.0, 0.0, 0, 0, 0)
# ('SUR4I56', 112, 'BR-116', 565.0, 145.0, 0.0, 0.0, 0, 0, 0)
# ('VEN0Q12', 112, 'BR-116', 835.0, 441.05, 31.7, 10.3, 0, 1, 0)
# ('VEN2O34', 112, 'BR-116', 385.0, 193.05, 67.5, 76.2, 1, 1, 0)
# ('VEN4E56', 112, 'BR-116', 745.0, 698.55, -42.15, 47.55, 0, 1, 0)
# ('BOL3R45', 113, 'BR-116', 475.0, 194.3, 0.0, 0.0, 0, 0, 0)
# ('BRA2A34', 113, 'BR-116', 385.0, 701.0, 152.55, 54.9, 0, 0, 0)
# ('SUR4I56', 113, 'BR-116', 565.0, 145.0, 0.0, 0.0, 0, 0, 0)
# ('VEN2O34', 113, 'BR-116', 385.0, 224.1, -45.15, 31.05, 0, 1, 0)
# ('BRA6W78', 114, 'BR-116', 745.0, 815.05, -6.833, -13.65, 1, 1, 0)
# ('PER1H23', 114, 'BR-116', 835.0, 852.0, -0.094, -1.25, 0, 0, 0)
